# %%
A=[[0, 0], [102, 29], [168, 114], [196, 205], [212, 270], [129, 189], [140, 245], [120, 170], [111, 157], [70, 195], [84, 247], [77, 159], [72, 162], [15, 194], [26, 248], [28, 166], [20, 162], [-38, 195], [-29, 229], [-18, 173], [-26, 163]]


N=[[0, 0], [90, 47], [123, 161], [74, 250], [31, 310], [128, 212], [148, 291], [126, 216], [104, 171], [64, 225], [91, 333], [81, 242], [66, 188], [0, 217], [16, 286], [17, 185], [13, 134], [-59, 199], [-36, 238], [-28, 176], [-29, 150]]

# %%
Nteste = [[0, 0], [81, 40], [113, 151], [78, 247], [51, 329], [142, 212], [175, 260], [147, 192], [116, 131], [81, 233], [132, 323], [122, 250], [97, 181], [14, 234], [39, 271], [37, 170], [31, 106], [-49, 224], [-12, 229], [-8, 158], [-14, 121]]

# %%
from scipy.spatial import distance
#dst = distance.euclidean(a, b)

# %%
np.mean([distance.euclidean(a, b) for a,b in zip(N,Nteste)])

# %%
a=[1,2]
b=[3,4]

dst = distance.euclidean(a, b)

# %%
dst

# %%
import numpy as np

# %%
np.mean([distance.euclidean(a, b) for a,b in zip(A,Nteste)])

# %%
np.mean([distance.euclidean(a, b) for a,b in zip(N,Nteste)])

# %%
dictletras={'A':A,'N':N}

# %%
dictletras['A']

# %%
type(dictletras)

# %%
dictletras.keys()

# %%
for letra in dictletras.keys():
    print(letra)
    print(dictletras[letra])

# %%
list(dictletras.keys())

# %%
ord('a')

# %%
chr(122)

# %%
[i for i in range(97,123)]

# %%
key=100

# %%
key in range(97,123)

# %%
testdict = {'a': [[0, 0], [80, 40], [124, 118], [134, 184], [143, 234], [88, 169], [86, 200], [76, 143], [70, 102], [42, 166], [41, 200], [38, 131], [35, 89], [-4, 157], [-6, 187], [3, 119], [9, 79], [-46, 144], [-48, 168], [-34, 119], [-25, 91]], 'q': [[0, 0], [-81, 38], [-132, 106], [-168, 161], [-186, 210], [-90, 208], [-129, 283], [-182, 265], [-206, 228], [-60, 213], [-141, 254], [-183, 192], [-179, 138], [-29, 205], [-122, 224], [-152, 154], [-143, 101], [4, 185], [-81, 199], [-109, 151], [-102, 109]]}

# %%
testdict.keys()

# %%
testdict['n']=[N]

# %%
testdict.keys()

# %%
testdict['n']

# %%
testdict['n']=testdict['n']+[N]

# %%
len(testdict['n'][0][0])

# %%
if testdict['d']:
    print('yes')
else:
    print('no')

# %%
testdict = {'a': [[[0, 0], [109, 24], [179, 133], [200, 238], [211, 307], [132, 218], [137, 279], [118, 190], [112, 181], [66, 218], [74, 275], [72, 173], [71, 178], [5, 211], [9, 269], [15, 173], [10, 171], [-53, 207], [-51, 244], [-38, 177], [-42, 166]], [[0, 0], [108, 47], [168, 156], [183, 256], [199, 324], [109, 234], [127, 293], [111, 201], [98, 191], [43, 230], [66, 287], [65, 186], [53, 188], [-18, 217], [1, 278], [11, 185], [-5, 181], [-74, 207], [-60, 247], [-41, 186], [-53
# %%
ola['a'][1]

# %%
import pandas as pd

# %%
ola.to_json('ola')

# %%
geeky_file = open('geekyfile.txt', 'wt')
geeky_file.write(str(ola))
geeky_file.close()

# %%
import pickle

# %%
ola.to_pickle('ola.p')

# %%
# load json module
import json

# python dictionary with key value pairs

# create json object from dictionary
json = json.dumps(ola)

# open file for writing, "w" 
f = open("dict.json","w")

# write json object to file
f.write(json)

# close file
f.close()

# %%
readola = open("dict.json","r")

# %%
helloq = pickle.load(open( "file.pkl", "rb" ))

# %%
dict(helloq)

# %%
import pickle
import numpy as np

# %%
from scipy.spatial import distance

# %%
teste_d=pickle.load(open( "dictletras1.pkl", "rb" ))

# %%
teste_d.keys()

# %%
teste_d['a'][1]

# %%
hand1=teste_d['b'][1]
hand2=teste_d['a'][1]
np.mean([distance.euclidean(a, b) for a,b in zip(hand1,hand2)])

# %%
teste_d=pickle.load(open( "dictletras2.pkl", "rb" ))

# %%
teste_d.keys()

# %%
hand1=teste_d['a'][0]
hand2=teste_d['a'][5]
np.mean([distance.euclidean(a, b) for a,b in zip(hand1,hand2)])

# %%
teste_d['a'][5]

# %%
teste_s={'s': [[[0, 0, 0], [83, 68, 37], [146, 179, 51], [193, 265, 64], [248, 316, 76], [59, 297, 16], [75, 410, 42], [85, 481, 66], [88, 544, 85], [-6, 301, 22], [-18, 422, 41], [-25, 499, 61], [-29, 565, 78], [-65, 277, 35], [-87, 386, 58], [-98, 454, 73], [-104, 515, 86], [-116, 236, 52], [-151, 313, 72], [-174, 366, 79], [-193, 416, 84]], [[0, 0, 0], [39, 30, 14], [71, 77, 19], [93, 112, 24], [116, 134, 28], [33, 132, 6], [41, 181, 17], [46, 211, 27], [50, 238, 36], [4, 134, 10], [2, 187, 18], [1, 220, 27], [1, 248, 34], [-22, 124, 16], [-30, 171, 26], [-35, 201, 33], [-37, 227, 39], [-44, 104, 24], [-59, 137, 33], [-69, 160, 37], [-77, 181, 40]]]}

# %%
teste_s.keys()

# %%
len(teste_s['s'])

# %%
teste_s['s'][0]

# %%
teste_s['s'][1]

# %%
teste_abc=pickle.load(open( "dictletras3.pkl", "rb" ))

# %%
len(teste_abc['c'])

# %%
teste_abc.keys()

# %%
teste_abc

# %%
htestar=teste_abc['b'][3]
hmin=teste_abc['a'][0]
dmin=np.mean([distance.euclidean(a, b) for a,b in zip(htestar, hmin)])
for letra in list(teste_abc.keys()):
    for h in teste_abc[letra]:
        d=np.mean([distance.euclidean(a, b) for a,b in zip(htestar, h)])
        if d<dmin:
            dmin=d
            letramin=letra
            
print(letramin)
print(dmin)

# %%
A=[[0, 0], [102, 29], [168, 114], [196, 205], [212, 270], [129, 189], [140, 245], [120, 170], [111, 157], [70, 195], [84, 247], [77, 159], [72, 162], [15, 194], [26, 248], [28, 166], [20, 162], [-38, 195], [-29, 229], [-18, 173], [-26, 163]]

# %%
list(teste_abc.keys())

# %%
Bteste=teste_abc['b'][0]

# %%
teste_abc['b']=teste_abc['b'][1:]

# %%
teste_abc['b']

# %%
Bteste

# %%
teste_abc

# %%
import pickle

teste_def=pickle.load(open( "dictletras4.pkl", "rb" ))

# %%
teste_def.keys()

# %%
teste_def['d']=teste_def['d'][1:]
teste_def['e']=teste_def['e'][1:]
teste_def['f']=teste_def['f'][1:]

# %%
D=teste_def['d'][0]
E=teste_def['e'][0]
F=teste_def['f'][0]

# %%
htestar=F
hmin=teste_def['d'][0]
dmin=np.mean([distance.euclidean(a, b) for a,b in zip(htestar, hmin)])
letramin='d'
for letra in list(teste_def.keys()):
    for h in teste_def[letra]:
        d=np.mean([distance.euclidean(a, b) for a,b in zip(htestar, h)])
        if d<dmin:
            dmin=d
            letramin=letra
            
print(letramin)
print(dmin)
# Out:
# f
# 12.763869077466252

# %%
import numpy as np

# %%
from scipy.spatial import distance

# %%
teste_ola=pickle.load(open( "dictletras4.pkl", "rb" ))

# %%
teste_abc=pickle.load(open( "dictletras3.pkl", "rb" ))

# %%
teste_def.update(teste_ola)

# %%
teste_abc.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd', 'e', 'f'])

# %%
htestar=F
hmin=teste_def['d'][0]
dmin=np.mean([distance.euclidean(a, b) for a,b in zip(htestar, hmin)])
letramin='d'
for letra in list(teste_def.keys()):
    for h in teste_def[letra]:
        d=np.mean([distance.euclidean(a, b) for a,b in zip(htestar, h)])
        if d<dmin:
            dmin=d
            letramin=letra
            
print(letramin)
print(dmin)
# Out:
# f
# 0.0

# %%
teste_def=teste_abc

# %%
teste_def.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd', 'e', 'f'])

# %%
teste_def['f']=teste_def['f'][1:]

# %%
F=teste_def['f'][0]

# %%
dict1=pickle.load(open( "dictletras_abc.pkl", "rb" ))
dict2=pickle.load(open( "dictletras_def.pkl", "rb" ))
dict3=pickle.load(open( "dictletras_ghi.pkl", "rb" ))

dict_asl={}

# %%
dict_asl.update(dict3)

# %%
dict_asl.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd', 'e', 'f'])

# %%
dict3
# Out:
# {}

# %%
dict3=pickle.load(open( "dictletras_ghi.pkl", "rb" ))

# %%
dict_asl
# Out:
# {'a': [[[0, 0],
#    [94, 12],
#    [166, 106],
#    [186, 204],
#    [200, 261],
#    [126, 181],
#    [135, 239],
#    [117, 167],
#    [107, 143],
#    [68, 185],
#    [82, 242],
#    [74, 155],
#    [68, 140],
#    [13, 183],
#    [24, 239],
#    [23, 153],
#    [16, 131],
#    [-44, 180],
#    [-33, 218],
#    [-28, 156],
#    [-34, 134]],
#   [[0, 0],
#    [104, 19],
#    [177, 121],
#    [200, 224],
#    [223, 289],
#    [135, 206],
#    [147, 261],
#    [126, 177],
#    [114, 159],
#    [72, 211],
#    [89, 266],
#    [81, 168],
#    [75, 159],
#    [13, 205],
#    [27, 261],
#    [27, 167],
#    [18, 151],
#    [-45, 199],
#    [-33, 234],
#    [-25, 168],
#    [-32, 152]],
#   [[0, 0],
#    [110, 31],
#    [185, 134],
#    [212, 239],
#    [234, 311],
#    [139, 229],
#    [157, 282],
#    [133, 191],
#    [120, 178],
#    [73, 231],
#    [95, 283],
#    [88, 180],
#    [80, 179],
#    [12, 222],
#    [30, 279],
#    [32, 180],
#    [21, 171],
#    [-47, 214],
# ...

# %%
dict3=pickle.load(open( "dictletras_ghi.pkl", "rb" ))

# %%
dict3.keys()
# Out:
# dict_keys(['g', 'h', 'i'])

# %%
dict3['k']=[]

# %%
dict3.('k')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/tx/jymtlyn96zb0qj_hvpjlfm5r0000gn/T/ipykernel_23728/1095758183.py in <module>
# ----> 1 dict3.remove('k')
#
# AttributeError: 'dict' object has no attribute 'remove'

# %%
dict3.pop("k", None)
# Out:
# []

# %%
dict_asl={}
dict1=pickle.load(open( "dictletras_abc.pkl", "rb" ))
dict2=pickle.load(open( "dictletras_def.pkl", "rb" ))
dict3=pickle.load(open( "dictletras_ghi.pkl", "rb" ))
dict4=pickle.load(open( "dictletras_klmno.pkl", "rb" ))

dict_asl.update(dict1)
dict_asl.update(dict2)
dict_asl.update(dict3)
dict_asl.update(dict4)

# %%
dict_asl.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'o'])

# %%
        # create a binary pickle file 
#f = open("dictletras_a_to_o.pkl","wb")
        # write the python object (dict) to pickle file
pickle.dump(dict_asl,f)
        # close file
f.close()

# %%
dict4=pickle.load(open( "dictletras_klmno.pkl", "rb" ))

# %%
dict4.keys()
# Out:
# dict_keys(['k', 'l', 'm', 'n', 'o'])

# %%
dict_p_to_t=pickle.load(open( "dictletras_pqrst.pkl", "rb" ))

# %%
dict_a_to_o=pickle.load(open( "dictletras_a_to_o.pkl", "rb" ))

# %%
dict_a_to_o.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 'r', 's', 't'])

# %%
dict_a_to_o.update(dict_p_to_t)

# %%
f = open("dictletras_a_to_t.pkl","wb")
        # write the python object (dict) to pickle file
pickle.dump(dict_a_to_o,f)
        # close file
f.close()

# %%
mode(['a','a','a','b'])
# Out:
# 'a'

# %%
from statistics import mode

# %%
not True
# Out:
# False

# %%
preds=[' ']

# %%
preds[-1]
# Out:
# ' '

# %%
''.join(preds).strip()
# Out:
# 'ana lolol bmb bab'

# %%
from gtts import gTTS
  
# This module is imported so that we can 
# play the converted audio
import os
  
# The text that you want to convert to audio
mytext = 'Welcome to geeksforgeeks!'
  
# Language in which you want to convert
language = 'en'
  
# Passing the text and language to the engine, 
# here we have marked slow=False. Which tells 
# the module that the converted audio should 
# have a high speed
myobj = gTTS(text=mytext, lang=language, slow=False)
  
# Saving the converted audio in a mp3 file named
# welcome 
myobj.save("welcome.mp3")
  
# Playing the converted file
os.system("mpg321 welcome.mp3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/tx/jymtlyn96zb0qj_hvpjlfm5r0000gn/T/ipykernel_23728/485091254.py in <module>
# ----> 1 from gtts import gTTS
#       2
#       3 # This module is imported so that we can
#       4 # play the converted audio
#       5 import os
#
# ModuleNotFoundError: No module named 'gtts'

# %%
import pyttsx3
engine = pyttsx3.init()
engine.setProperty('rate', 150) 
engine.setProperty('voice', 'com.apple.speech.synthesis.voice.moira') 
engine.say('hello my name is ana')
engine.runAndWait()

# %%
# !pip install pyttsx3
# Out:
# ...
#   Using cached pyttsx3-2.90-py3-none-any.whl (39 kB)
# ...

# %%
## descobrir as vozes que tens no pc
voices = engine.getProperty('voices')
for voice in voices:
    if (voice.languages == ['en_US']) | (voice.languages == ['en_GB']) | (voice.languages == ['en_IE']):
        print("Voice: %s" % voice.name)
        print(" - ID: %s" % voice.id)
        print(" - Languages: %s" % voice.languages)
        print(" - Gender: %s" % voice.gender)
        print(" - Age: %s" % voice.age)
# Out:
# Voice: Alex
#  - ID: com.apple.speech.synthesis.voice.Alex
#  - Languages: ['en_US']
#  - Gender: VoiceGenderMale
#  - Age: 35
# Voice: Daniel
#  - ID: com.apple.speech.synthesis.voice.daniel
#  - Languages: ['en_GB']
#  - Gender: VoiceGenderMale
#  - Age: 35
# Voice: Fred
#  - ID: com.apple.speech.synthesis.voice.Fred
#  - Languages: ['en_US']
#  - Gender: VoiceGenderMale
#  - Age: 30
# Voice: Moira
#  - ID: com.apple.speech.synthesis.voice.moira
#  - Languages: ['en_IE']
#  - Gender: VoiceGenderFemale
#  - Age: 35
# Voice: Samantha
#  - ID: com.apple.speech.synthesis.voice.samantha
#  - Languages: ['en_US']
#  - Gender: VoiceGenderFemale
#  - Age: 35
# Voice: Victoria
#  - ID: com.apple.speech.synthesis.voice.Victoria
#  - Languages: ['en_US']
#  - Gender: VoiceGenderFemale
#  - Age: 35

# %%
engine.getProperty('voices')

# %%
hpred = A
hmin_list = dict_asl["a"]
dmin_list = [np.mean([distance.euclidean(a, b) for a, b in zip(hpred, hmin)]) for hmin in hmin_list]
letramin_list = []
for letra in list(dict_asl.keys()):
    for h in dict_asl[letra]:
        d = np.mean([distance.euclidean(a, b) for a, b in zip(hpred, h)])
        if d < dmin:
            dmin = d
            letramin = letra
print(letramin)
preds.append(letramin)
# Out:
# a

# %%
A=[[0, 0], [102, 29], [168, 114], [196, 205], [212, 270], [129, 189], [140, 245], [120, 170], [111, 157], [70, 195], [84, 247], [77, 159], [72, 162], [15, 194], [26, 248], [28, 166], [20, 162], [-38, 195], [-29, 229], [-18, 173], [-26, 163]]

# %%
dict_asl = pickle.load(open("dictletras_a_to_t.pkl", "rb"))

# %%
import pandas as pd

# %%
le=[]
for k in list(dict_asl.keys()):
    le.append(len(dict_asl[k]))

# %%
le
# Out:
# [38, 20, 20, 16, 26, 27, 20, 20, 25, 31, 35, 31, 16, 38, 40, 30, 45, 29, 40]

# %%
dict_asl_1= pickle.load(open("dictletras_a_to_t.pkl", "rb"))

# %%
my_dict2 = {y:x for x,y in my_dict.iteritems()}

# %%
dict_asl_1
# Out:
# {'a': [[[0, 0],
#    [94, 12],
#    [166, 106],
#    [186, 204],
#    [200, 261],
#    [126, 181],
#    [135, 239],
#    [117, 167],
#    [107, 143],
#    [68, 185],
#    [82, 242],
#    [74, 155],
#    [68, 140],
#    [13, 183],
#    [24, 239],
#    [23, 153],
#    [16, 131],
#    [-44, 180],
#    [-33, 218],
#    [-28, 156],
#    [-34, 134]],
#   [[0, 0],
#    [104, 19],
#    [177, 121],
#    [200, 224],
#    [223, 289],
#    [135, 206],
#    [147, 261],
#    [126, 177],
#    [114, 159],
#    [72, 211],
#    [89, 266],
#    [81, 168],
#    [75, 159],
#    [13, 205],
#    [27, 261],
#    [27, 167],
#    [18, 151],
#    [-45, 199],
#    [-33, 234],
#    [-25, 168],
#    [-32, 152]],
#   [[0, 0],
#    [110, 31],
#    [185, 134],
#    [212, 239],
#    [234, 311],
#    [139, 229],
#    [157, 282],
#    [133, 191],
#    [120, 178],
#    [73, 231],
#    [95, 283],
#    [88, 180],
#    [80, 179],
#    [12, 222],
#    [30, 279],
#    [32, 180],
#    [21, 171],
#    [-47, 214],
# ...

# %%
new_dict={}
for k in list(dict_asl_1.keys()):
    for p in dict_asl_1[k]:
        print(p)
        new_dict[tuple(p)]=k
# Out:
# [[0, 0], [94, 12], [166, 106], [186, 204], [200, 261], [126, 181], [135, 239], [117, 167], [107, 143], [68, 185], [82, 242], [74, 155], [68, 140], [13, 183], [24, 239], [23, 153], [16, 131], [-44, 180], [-33, 218], [-28, 156], [-34, 134]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/tx/jymtlyn96zb0qj_hvpjlfm5r0000gn/T/ipykernel_23728/4168874086.py in <module>
#       3     for p in dict_asl_1[k]:
#       4         print(p)
# ----> 5         new_dict[tuple(p)]=k
#       6
#       7
#
# TypeError: unhashable type: 'list'

# %%
list(dict_asl_1.keys())
# Out:
# ['a',
#  'b',
#  'c',
#  'd',
#  'e',
#  'f',
#  'g',
#  'h',
#  'i',
#  'k',
#  'l',
#  'm',
#  'n',
#  'o',
#  'p',
#  'q',
#  'r',
#  's',
#  't']

# %%
dict_asl_1.keys()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/tx/jymtlyn96zb0qj_hvpjlfm5r0000gn/T/ipykernel_23728/1697886213.py in <module>
# ----> 1 dict_asl_1.keys()[0]
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
type(dict_asl_1)
# Out:
# dict

# %%
tuple([1,2,3])
# Out:
# (1, 2, 3)

# %%
new_dict[tuple([[1,2,3]])]='a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/tx/jymtlyn96zb0qj_hvpjlfm5r0000gn/T/ipykernel_23728/584001540.py in <module>
# ----> 1 new_dict[tuple([[1,2,3]])]='a'
#
# TypeError: unhashable type: 'list'

# %%
new_dict
# Out:
# {(1, 2, 3): 'a'}

# %%
hpred = A
hmin_list = dict_asl["a"]
dmin_list = [np.mean([distance.euclidean(a, b) for a, b in zip(hpred, hmin)]) for hmin in hmin_list]
letramin_list = []
for letra in list(dict_asl.keys()):
    for h in dict_asl[letra]:
        d = np.mean([distance.euclidean(a, b) for a, b in zip(hpred, h)])
        if d < dmin:
            dmin = d
            letramin = letra
print(letramin)
preds.append(letramin)
# Out:
# a

# %%
import pyttsx3

engine = pyttsx3.init()
engine.setProperty("rate", 150)
engine.setProperty("voice", "com.apple.speech.synthesis.voice.moira")

engine.say('hi')
engine.runAndWait()
print('ola')
# Out:
# ola
