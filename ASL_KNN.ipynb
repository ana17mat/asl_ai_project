# %%
import pickle

dict_asl = pickle.load(open("dictletras_a_to_t.pkl", "rb"))

# %%
import numpy as np
import pandas as pd

# %%
dhl=[]
for k in list(dict_asl.keys()):
    for h in dict_asl[k]:
        dict_h={}
        for i in range(21):
            dict_h['x'+str(i)]=h[i][0]
            dict_h['y'+str(i)]=h[i][1]
        dict_h['label']=k
        dhl.append(dict_h)

# %%
dataframe_asl=pd.DataFrame(dhl)

# %%
pd.set_option('display.max_columns', 400)

# %%
dataframe_asl
# Out:
#      x0  y0   x1  y1   x2   y2   x3   y3   x4   y4   x5   y5   x6   y6   x7  \
# 0     0   0   94  12  166  106  186  204  200  261  126  181  135  239  117
# 1     0   0  104  19  177  121  200  224  223  289  135  206  147  261  126
# 2     0   0  110  31  185  134  212  239  234  311  139  229  157  282  133
# 3     0   0  103  34  172  124  197  219  210  284  129  208  143  262  124
# 4     0   0  100  24  163  111  183  200  198  257  123  181  134  238  118
# ..   ..  ..  ...  ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 542   0   0   71  76   86  178   61  261   43  325   66  227   73  307   64
# 543   0   0   74  64   95  166   70  253   67  321   80  219  106  301   96
# 544   0   0   73  68   93  167   71  250   61  315   76  220  102  297   92
# 545   0   0   60  51   77  128   56  196   44  249   67  170   86  237   77
# 546   0   0   61  47   84  131   67  204   61  261   77  180   99  244   85
#
#       y7   x8   y8  x9   y9  x10  y10  x11  y11  x12  y12  x13  y13  x14  y14  \
# 0    167  107  143  68  185   82  242   74  155   68  140   13  183   24  239
# 1    177  114  159  72  211   89  266   81  168   75  159   13  205   27  261
# 2    191  120  178  73  231   95  283   88  180   80  179   12  222   30  279
# 3    185  113  163  72  212   87  263   79  171   74  162   16  207   30  260
# 4    169  107  143  69  185   82  240   76  156   69  139   17  182   29  239
# ..   ...  ...  ...  ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 542  261   55  202  12  214    1  263    9  187   17  123  -41  190  -47  232
# 543  256   83  200  20  213   29  261   31  176   34  112  -37  193  -25  230
# 544  245   77  188  19  210   28  251   30  169   31  106  -35  191  -25  217
# 545  200   68  155  21  164   26  209   28  146   31   93  -24  149  -17  184
# 546  203   72  156  28  176   37  214   33  145   34   91  -19  163  -10  192
#
#      x15  y15  x16  y16  x17  y17  x18  y18  x19  y19  x20  y20 label
# 0     23  153   16  131  -44  180  -33  218  -28  156  -34  134     a
# 1     27  167   18  151  -45  199  -33  234  -25  168  -32  152     a
# 2     32  180   21  171  -47  214  -33  250  -21  182  -28  169     a
# 3     29  172   21  155  -43  199  -28  238  -21  176  -27  156     a
# 4     28  157   20  132  -38  177  -25  217  -19  159  -25  135     a
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 542  -27  154  -12   94  -91  157  -90  199  -67  143  -53   97     t
# 543   -9  140    1   79  -91  166  -71  199  -51  139  -41   97     t
# 544  -10  131    0   73  -85  166  -68  192  -49  133  -40   92     t
# 545   -4  115    5   65  -67  128  -50  157  -35  110  -28   76     t
# 546   -2  118    6   67  -64  145  -48  167  -36  116  -29   81     t
#
# [547 rows x 43 columns]

# %%
features = pd.DataFrame(dataframe_asl.drop('label', axis=1))

features.head()
# Out:
#    x0  y0   x1  y1   x2   y2   x3   y3   x4   y4   x5   y5   x6   y6   x7  \
# 0   0   0   94  12  166  106  186  204  200  261  126  181  135  239  117
# 1   0   0  104  19  177  121  200  224  223  289  135  206  147  261  126
# 2   0   0  110  31  185  134  212  239  234  311  139  229  157  282  133
# 3   0   0  103  34  172  124  197  219  210  284  129  208  143  262  124
# 4   0   0  100  24  163  111  183  200  198  257  123  181  134  238  118
#
#     y7   x8   y8  x9   y9  x10  y10  x11  y11  x12  y12  x13  y13  x14  y14  \
# 0  167  107  143  68  185   82  242   74  155   68  140   13  183   24  239
# 1  177  114  159  72  211   89  266   81  168   75  159   13  205   27  261
# 2  191  120  178  73  231   95  283   88  180   80  179   12  222   30  279
# 3  185  113  163  72  212   87  263   79  171   74  162   16  207   30  260
# 4  169  107  143  69  185   82  240   76  156   69  139   17  182   29  239
#
#    x15  y15  x16  y16  x17  y17  x18  y18  x19  y19  x20  y20
# 0   23  153   16  131  -44  180  -33  218  -28  156  -34  134
# 1   27  167   18  151  -45  199  -33  234  -25  168  -32  152
# 2   32  180   21  171  -47  214  -33  250  -21  182  -28  169
# 3   29  172   21  155  -43  199  -28  238  -21  176  -27  156
# 4   28  157   20  132  -38  177  -25  217  -19  159  -25  135

# %%
labels = pd.Series(dataframe_asl['label'])

labels.head()
# Out:
# 0    a
# 1    a
# 2    a
# 3    a
# 4    a
# Name: label, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train=features
y_train=labels

# %%
from sklearn. neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)

knn
# Out:
# KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
A=[[0, 0], [102, 29], [168, 114], [196, 205], [212, 270], [129, 189], [140, 245], [120, 170], [111, 157], [70, 195], [84, 247], [77, 159], [72, 162], [15, 194], [26, 248], [28, 166], [20, 162], [-38, 195], [-29, 229], [-18, 173], [-26, 163]]

N=[[0, 0], [90, 47], [123, 161], [74, 250], [31, 310], [128, 212], [148, 291], [126, 216], [104, 171], [64, 225], [91, 333], [81, 242], [66, 188], [0, 217], [16, 286], [17, 185], [13, 134], [-59, 199], [-36, 238], [-28, 176], [-29, 150]]

# %%
knn.score(X_train, y_train)
# Out:
# 0.9908592321755028

# %%
knn.predict([N_flat])[0]
# Out:
# /Users/anamatias/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 'n'

# %%
A_flat = [item for sublist in A for item in sublist]

# %%
N_flat = [item for sublist in N for item in sublist]

# %%
import pickle

pickle.dump(knn, open('knn_asl.p','wb'))
